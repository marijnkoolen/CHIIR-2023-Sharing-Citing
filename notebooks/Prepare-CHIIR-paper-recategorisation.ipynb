# %%
import requests


def read_code_schema():
    response = requests.get(spreadsheet_urls['code_schema'])
    rows = response.text.split('\r\n')
    headers = rows.pop(0).split('\t')
    schema = []
    level1 = None
    level2 = None
    for row in rows:
        row_cells = row.split('\t')
        row_json = {header: row_cells[hi] for hi, header in enumerate(headers)}
        if row_json['Level 1'] != '':
            level1 = row_json['Level 1']
        else:
            row_json['Level 1'] = level1
        if row_json['Level 2'] != '':
            level2 = row_json['Level 2']
        else:
            row_json['Level 2'] = level2            
        schema.append(row_json)
    return schema


spreadsheet_urls = {
    'code_schema': 'https://docs.google.com/spreadsheets/d/1gwXlwLR-kc1wNyKTfBA5ZyVuUq_WXjl55neSq763eC0/export?gid=736749451&format=tsv'
}

code_schema = read_code_schema()

# %%
domain_codes = [code_info for code_info in code_schema if code_info['Level 1'] == 'Domain']
domain_tags = [code_info['Copy-paste strings'] for code_info in domain_codes]
domain_tags
# Out:
# ['domain;aerospace',
#  'domain;books',
#  'domain;children',
#  'domain;conversational agents',
#  'domain;creativity',
#  'domain;data',
#  'domain;digital library ',
#  'domain;disabilities',
#  'domain;DIY',
#  'domain;e-commerce',
#  'domain;education',
#  'domain;games',
#  'domain;government',
#  'domain;health',
#  'domain;history',
#  'domain;learning',
#  'domain;legal',
#  'domain;libraries',
#  'domain;literature',
#  'domain;misinformation',
#  'domain;movies',
#  'domain;multilinguality',
#  'domain;museum',
#  'domain;music',
#  'domain;news',
#  'domain;older people',
#  'domain;politics',
#  'domain;privacy',
#  'domain;research',
#  'domain;science',
#  'domain;social media',
#  'domain;social sciences',
#  'domain;visualization',
#  'domain;wikipedia',
#  'domain;WWW',
#  'domain;...',
#  'domain;domain-agnostic',
#  'domain;unknown',
#  'domain;IIR',
#  'domain;search engines',
#  'domain;search',
#  'domain;mobile search',
#  'domain;digital libraries',
#  'domain;search-as-learning',
#  'domain;collaborative search',
#  'domain;personal information',
#  'domain;exploratory search',
#  'domain;images',
#  'domain;e-mail',
#  'domain;question answering',
#  'domain;recommender systems',
#  'domain;information seeking',
#  'domain;evaluation',
#  'domain;Wikipedia',
#  'domain;',
#  'domain;videos',
#  'domain;archives/museums',
#  'domain;UX',
#  'domain;information literacy',
#  'domain;relevance assessment',
#  'domain;data visualization',
#  'domain;mobile devices',
#  'domain;memory',
#  'domain;personal information management',
#  'domain;tourism',
#  'domain;text',
#  'domain;speech',
#  'domain:IIR',
#  'domain;medical',
#  'domain;crowdsourcing',
#  'domain;research data',
#  'domain;distraction',
#  'domain;trust',
#  'domain;Twitter',
#  'domain;digital humanities',
#  'domain;serendipity',
#  'domain;diversity',
#  'domain;methodology',
#  'domain;tasks',
#  'domain;usability',
#  'domain;web archiving',
#  'domain:WWW',
#  'domain;ir',
#  'domain;personalization',
#  'domain;profiling',
#  'domain; user engagement',
#  'domain;academic',
#  'domain;collaboration',
#  'domain;health;cancer',
#  'domain;crime',
#  'domain;life-logging',
#  'domain;cross-session search',
#  'domain;AR/VR',
#  'domain;government;NSA',
#  'domain;LGBTQ+',
#  'domain;advertising',
#  'domain;daily activities',
#  'domain;messenger;Slack',
#  'domain;digital assistant',
#  'domain;desktop',
#  'domain;entity search',
#  'domain;air quality',
#  'domain;information behavior',
#  'domain;finance',
#  'domain;augmented reality',
#  'domain;productivity software',
#  'domain;design',
#  'domain;journalism',
#  'domain;proactive IR',
#  'domain;chatbots',
#  'domain;user behavior',
#  'domain;reading',
#  'domain;patents',
#  'domain;search assistance',
#  'domain;TV',
#  'domain;audio visual',
#  'domain;e-services',
#  'domain;intranet',
#  'domain;query suggestion',
#  'domain;summarization',
#  'domain;CLIR',
#  'domain;visualization;non verbal access',
#  'domain;disabilities;dyslexia',
#  'domain;health;dyslexia',
#  'domain;3D objects',
#  'domain;search engines;advertisement',
#  'domain;real-time summarization',
#  'domain;e-commerce;amazon',
#  'domain;food',
#  'domain;complex search',
#  'domain;ethics',
#  'domain;food;recipe recommendation',
#  'domain;audio',
#  'domain;IT',
#  'domain;iir',
#  'domain;theatre',
#  'domain;digital library',
#  'domain;academic search',
#  'domain:social media']

# %%
domain_codes
# Out:
# [{'Level 1': 'Domain',
#   'Level 2': 'Aerospace',
#   'Example': '',
#   'Copy-paste strings': 'domain;aerospace',
#   'Note': 'although this is perphaps also the work context, I assume the most important aspect here is that the documents focus on aerospace information.',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Books / E-Books',
#   'Example': '',
#   'Copy-paste strings': 'domain;books',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Children',
#   'Example': '',
#   'Copy-paste strings': 'domain;children',
#   'Note': '',
#   'Category': 'user:group'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Conversational agents',
#   'Example': '',
#   'Copy-paste strings': 'domain;conversational agents',
#   'Note': '',
#   'Category': 'application:technology'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Creativity',
#   'Example': '',
#   'Copy-paste strings': 'domain;creativity',
#   'Note': '',
#   'Category': 'task:work;user:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Data',
#   'Example': '',
#   'Copy-paste strings': 'domain;data',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Digital Library ',
#   'Example': '',
#   'Copy-paste strings': 'domain;digital library ',
#   'Note': 'nothing about task or user or document, so application',
#   'Category': 'application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Disabilities',
#   'Example': '',
#   'Copy-paste strings': 'domain;disabilities',
#   'Note': 'better:impairment?',
#   'Category': 'user:issue;user:group'},
#  {'Level 1': 'Domain',
#   'Level 2': 'DIY',
#   'Example': '',
#   'Copy-paste strings': 'domain;DIY',
#   'Note': 'work context includes work task and types of document',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'E-commerce',
#   'Example': '',
#   'Copy-paste strings': 'domain;e-commerce',
#   'Note': 'work context includes work task and types of document',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Education',
#   'Example': '',
#   'Copy-paste strings': 'domain;education',
#   'Note': 'work context includes work task and types of document',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Games ',
#   'Example': '',
#   'Copy-paste strings': 'domain;games',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Government',
#   'Example': '',
#   'Copy-paste strings': 'domain;government',
#   'Note': '',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Health',
#   'Example': '',
#   'Copy-paste strings': 'domain;health',
#   'Note': 'work context includes work task and types of document',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'History',
#   'Example': '',
#   'Copy-paste strings': 'domain;history',
#   'Note': 'this is about the topic of the documents but also about the work context (historical research)',
#   'Category': 'document:topic;task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Learning, search-as-learning',
#   'Example': '',
#   'Copy-paste strings': 'domain;learning',
#   'Note': '',
#   'Category': 'task:context'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Legal',
#   'Example': '',
#   'Copy-paste strings': 'domain;legal',
#   'Note': '',
#   'Category': 'document:topic;task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Libraries',
#   'Example': '',
#   'Copy-paste strings': 'domain;libraries',
#   'Note': '',
#   'Category': 'task:context'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Literature / Publications',
#   'Example': '',
#   'Copy-paste strings': 'domain;literature',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Misinformation',
#   'Example': '',
#   'Copy-paste strings': 'domain;misinformation',
#   'Note': 'is this a domain? property of documents?',
#   'Category': 'document:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Movies',
#   'Example': '',
#   'Copy-paste strings': 'domain;movies',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Multilinguality ',
#   'Example': '',
#   'Copy-paste strings': 'domain;multilinguality',
#   'Note': 'is this a domain? property of documents?',
#   'Category': 'document:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Museum',
#   'Example': '',
#   'Copy-paste strings': 'domain;museum',
#   'Note': 'setting, nothing about user, document or task',
#   'Category': 'task:context'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Music',
#   'Example': '',
#   'Copy-paste strings': 'domain;music',
#   'Note': 'docs are songs, so music is not the topic',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': 'News',
#   'Example': '',
#   'Copy-paste strings': 'domain;news',
#   'Note': '',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Older people',
#   'Example': '',
#   'Copy-paste strings': 'domain;older people',
#   'Note': '',
#   'Category': 'user:group'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Politics',
#   'Example': '',
#   'Copy-paste strings': 'domain;politics',
#   'Note': '',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Privacy',
#   'Example': '',
#   'Copy-paste strings': 'domain;privacy',
#   'Note': 'is this a domain? property of user and application',
#   'Category': 'user:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Research, academic search',
#   'Example': '',
#   'Copy-paste strings': 'domain;research',
#   'Note': 'different from literature/publications?',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Science',
#   'Example': '',
#   'Copy-paste strings': 'domain;science',
#   'Note': '',
#   'Category': 'document:topic;task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Social Media ',
#   'Example': '',
#   'Copy-paste strings': 'domain;social media',
#   'Note': 'no topic, nor type',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Social Sciences',
#   'Example': '',
#   'Copy-paste strings': 'domain;social sciences',
#   'Note': '',
#   'Category': 'document:topic;task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Visualizations',
#   'Example': '',
#   'Copy-paste strings': 'domain;visualization',
#   'Note': 'is this a domain? feature of interface/application',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Wikipedia',
#   'Example': '',
#   'Copy-paste strings': 'domain;wikipedia',
#   'Note': '',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': 'WWW',
#   'Example': '',
#   'Copy-paste strings': 'domain;WWW',
#   'Note': '',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': '...',
#   'Example': '',
#   'Copy-paste strings': 'domain;...',
#   'Note': '',
#   'Category': '~'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Domain-agnostic',
#   'Example': '',
#   'Copy-paste strings': 'domain;domain-agnostic',
#   'Note': '',
#   'Category': '~'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;unknown',
#   'Note': '',
#   'Category': '~'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;IIR',
#   'Note': '',
#   'Category': 'research'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;search engines',
#   'Note': 'this almost always refers to web search, in which case, the search engine is an application (a web search engine)',
#   'Category': 'application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;search',
#   'Note': '',
#   'Category': 'task'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;mobile search',
#   'Note': 'device',
#   'Category': 'application:device'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;digital libraries',
#   'Note': 'same as digital library',
#   'Category': 'application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;search-as-learning',
#   'Note': 'same as learning',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;collaborative search',
#   'Note': '',
#   'Category': 'task'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;personal information',
#   'Note': '',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;exploratory search',
#   'Note': '',
#   'Category': 'task'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;images',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;e-mail',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;question answering',
#   'Note': '',
#   'Category': 'task'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;recommender systems',
#   'Note': '',
#   'Category': 'application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;information seeking',
#   'Note': '',
#   'Category': 'task'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;evaluation',
#   'Note': 'is this a domain',
#   'Category': 'research:process'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;Wikipedia',
#   'Note': 'same as wikipedia',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;',
#   'Note': '?',
#   'Category': '~'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;videos',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;archives/museums',
#   'Note': '',
#   'Category': 'task:context'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;UX',
#   'Note': 'is this a domain',
#   'Category': 'research:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;information literacy',
#   'Note': '',
#   'Category': 'user:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;relevance assessment',
#   'Note': '',
#   'Category': 'research:process'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;data visualization',
#   'Note': '',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;mobile devices',
#   'Note': '',
#   'Category': 'application:device'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;memory',
#   'Note': '',
#   'Category': 'user:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;personal information management',
#   'Note': '',
#   'Category': 'task'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;tourism',
#   'Note': 'more task-related than document related',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;text',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;speech',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain:IIR',
#   'Note': '',
#   'Category': 'research'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;medical',
#   'Note': '',
#   'Category': 'document:genre;task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;crowdsourcing',
#   'Note': 'crowdsourcing is not the actual task',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;research data',
#   'Note': '',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;distraction',
#   'Note': '',
#   'Category': 'user:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;trust',
#   'Note': '',
#   'Category': 'user:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;Twitter',
#   'Note': 'use of Twitter as application',
#   'Category': 'application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;digital humanities',
#   'Note': '',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;serendipity',
#   'Note': '',
#   'Category': 'user:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;diversity',
#   'Note': '',
#   'Category': 'document:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;methodology',
#   'Note': '',
#   'Category': 'research:process'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;tasks',
#   'Note': '',
#   'Category': 'research:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;usability',
#   'Note': '',
#   'Category': 'application:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;web archiving',
#   'Note': '',
#   'Category': 'application:technology'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain:WWW',
#   'Note': '',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;ir',
#   'Note': '',
#   'Category': 'research:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;personalization',
#   'Note': '',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;profiling',
#   'Note': '',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain; user engagement',
#   'Note': '',
#   'Category': 'research:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;academic',
#   'Note': 'students reading academic documents',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;collaboration',
#   'Note': '',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;health;cancer',
#   'Note': '',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;crime',
#   'Note': '',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;life-logging',
#   'Note': '',
#   'Category': 'application:technology'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;cross-session search',
#   'Note': '',
#   'Category': 'task'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;AR/VR',
#   'Note': '',
#   'Category': 'application:technology'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;government;NSA',
#   'Note': '',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;LGBTQ+',
#   'Note': '',
#   'Category': 'user'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;advertising',
#   'Note': '',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;daily activities',
#   'Note': '',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;messenger;Slack',
#   'Note': '',
#   'Category': 'application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;digital assistant',
#   'Note': '',
#   'Category': 'application:technology'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;desktop',
#   'Note': 'could also be device',
#   'Category': 'application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;entity search',
#   'Note': '',
#   'Category': 'task'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;air quality',
#   'Note': '',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;information behavior',
#   'Note': '',
#   'Category': 'user:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;finance',
#   'Note': '',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;augmented reality',
#   'Note': '',
#   'Category': 'application:technology'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;productivity software',
#   'Note': '',
#   'Category': 'application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;design',
#   'Note': '',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;journalism',
#   'Note': '',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;proactive IR',
#   'Note': 'application suggesting tasks, strategies, problems (information fostering)',
#   'Category': 'research:issue;application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;chatbots',
#   'Note': '',
#   'Category': 'application:technology'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;user behavior',
#   'Note': '',
#   'Category': 'user:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;reading',
#   'Note': '',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;patents',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;search assistance',
#   'Note': '',
#   'Category': 'application:technology'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;TV',
#   'Note': '',
#   'Category': 'document:genre'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;audio visual',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;e-services',
#   'Note': 'this is about offering (government) services in a digital format',
#   'Category': '~'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;intranet',
#   'Note': 'intranet search, is this application:technology? ',
#   'Category': '~'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;query suggestion',
#   'Note': '',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;summarization',
#   'Note': '',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;CLIR',
#   'Note': '',
#   'Category': 'document:issue;research:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;visualization;non verbal access',
#   'Note': '',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;disabilities;dyslexia',
#   'Note': '',
#   'Category': 'user'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;health;dyslexia',
#   'Note': '',
#   'Category': 'user'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;3D objects',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;search engines;advertisement',
#   'Note': '',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;real-time summarization',
#   'Note': '',
#   'Category': 'application:feature'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;e-commerce;amazon',
#   'Note': '',
#   'Category': 'task:work'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;food',
#   'Note': '',
#   'Category': 'document:topic'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;complex search',
#   'Note': '',
#   'Category': 'task'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;ethics',
#   'Note': '',
#   'Category': 'research:issue'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;food;recipe recommendation',
#   'Note': '',
#   'Category': 'document:topic;application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;audio',
#   'Note': '',
#   'Category': 'document:media type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;IT',
#   'Note': '',
#   'Category': 'document:type'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;iir',
#   'Note': '',
#   'Category': 'research'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;theatre',
#   'Note': '',
#   'Category': 'task:context'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;digital library',
#   'Note': '',
#   'Category': 'application'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain;academic search',
#   'Note': '',
#   'Category': 'task:context'},
#  {'Level 1': 'Domain',
#   'Level 2': 'Unknown',
#   'Example': '',
#   'Copy-paste strings': 'domain:social media',
#   'Note': '',
#   'Category': 'document:genre'}]

# %%
from collections import Counter


def read_zotero_file(zotero_file):
    with open(zotero_file, 'rt') as fh:
        for line in fh:
            if len(line.strip()) == 0:
                continue
            elif line.startswith('<'):
                continue
            try:
                code, tag = line.strip().split(' ', 1)
                yield code, tag
            except ValueError:
                print(line)
                raise
    
tag_freq = Counter()
zotero_file = '../data/zotero/BIRRD-Zotero/BIRRD-Zotero.txt'


for code, tag in read_zotero_file(zotero_file):
    if code != 'K1':
        continue
    tag_freq.update([tag])
    
for tag, freq in tag_freq.most_common():
    if tag.startswith('domain'):
        if tag in domain_codes:
            continue
        print(tag)
        #print(f"{tag: <40}{freq: >8}")
# Out:
# domain;IIR
# domain;search engines
# domain;search
# domain;social media
# domain;mobile search
# domain;digital libraries
# domain;search-as-learning
# domain;collaborative search
# domain;personal information
# domain;exploratory search
# domain;images
# domain;e-mail
# domain;question answering
# domain;recommender systems
# domain;information seeking
# domain;evaluation
# domain;Wikipedia
# domain;
# domain;videos
# domain;archives/museums
# domain;UX
# domain;information literacy
# domain;relevance assessment
# domain;data visualization
# domain;mobile devices
# domain;memory
# domain;personal information management
# domain;tourism
# domain;text
# domain;speech
# domain:IIR
# domain;medical
# domain;crowdsourcing
# domain;research data
# domain;distraction
# domain;trust
# domain;Twitter
# domain;digital humanities
# domain;serendipity
# domain;diversity
# domain;methodology
# domain;tasks
# domain;usability
# domain;web archiving
# domain:WWW
# domain;ir
# domain;personalization
# domain;profiling
# domain; user engagement
# domain;academic
# domain;collaboration
# domain;health;cancer
# domain;crime
# domain;life-logging
# domain;cross-session search
# domain;AR/VR
# domain;government;NSA
# domain;LGBTQ+
# domain;advertising
# domain;daily activities
# domain;messenger;Slack
# domain;digital assistant
# domain;desktop
# domain;entity search
# domain;air quality
# domain;information behavior
# domain;finance
# domain;augmented reality
# domain;productivity software
# domain;design
# domain;journalism
# domain;proactive IR
# domain;chatbots
# domain;user behavior
# domain;reading
# domain;patents
# domain;search assistance
# domain;TV
# domain;audio visual
# domain knowledge
# domain;e-services
# domain;intranet
# domain;query suggestion
# domain;summarization
# domain;CLIR
# domain;visualization;non verbal access
# domain;disabilities;dyslexia
# domain;health;dyslexia
# domain;3D objects
# domain;search engines;advertisement
# domain;real-time summarization
# domain;e-commerce;amazon
# domain;food
# domain;complex search
# domain;ethics
# domain;food;recipe recommendation
# domain;audio
# domain;IT
# domain;iir
# domain;theatre
# domain;digital library
# domain;academic search
# domain:social media

# %%
for code_info in domain_codes:
    domain = code_info['Copy-paste strings'].replace('domain;', '').replace('domain:', '').strip()
    categories = code_info['Category'].split(';')
    specific_cats = [f"{cat}:{domain.replace(' ', '_').replace(';', ':')}" for cat in categories]
    print('; '.join(specific_cats))
# Out:
# document:topic:aerospace
# document:type:books
# user:group:children
# application:technology:conversational_agents
# task:work:creativity; user:issue:creativity
# document:type:data
# application:digital_library
# user:issue:disabilities; user:group:disabilities
# task:work:DIY
# task:work:e-commerce
# task:work:education
# document:type:games
# document:topic:government
# document:topic:health
# document:topic:history; task:work:history
# task:context:learning
# document:topic:legal; task:work:legal
# task:context:libraries
# document:type:literature
# document:issue:misinformation
# document:type:movies
# document:issue:multilinguality
# task:context:museum
# document:genre:music
# document:genre:news
# user:group:older_people
# document:topic:politics
# user:issue:privacy
# task:work:research
# document:topic:science; task:work:science
# document:genre:social_media
# document:topic:social_sciences; task:work:social_sciences
# application:feature:visualization
# document:genre:wikipedia
# document:genre:WWW
# ~:...
# ~:domain-agnostic
# ~:unknown
# research:IIR
# application:search_engines
# task:search
# application:device:mobile_search
# application:digital_libraries
# task:work:search-as-learning
# task:collaborative_search
# document:genre:personal_information
# task:exploratory_search
# document:type:images
# document:type:e-mail
# task:question_answering
# application:recommender_systems
# task:information_seeking
# research:process:evaluation
# document:genre:Wikipedia
# ~:
# document:type:videos
# task:context:archives/museums
# research:issue:UX
# user:issue:information_literacy
# research:process:relevance_assessment
# application:feature:data_visualization
# application:device:mobile_devices
# user:issue:memory
# task:personal_information_management
# task:work:tourism
# document:type:text
# document:type:speech
# research:IIR
# document:genre:medical; task:work:medical
# task:work:crowdsourcing
# document:genre:research_data
# user:issue:distraction
# user:issue:trust
# application:Twitter
# task:work:digital_humanities
# user:issue:serendipity
# document:issue:diversity
# research:process:methodology
# research:issue:tasks
# application:issue:usability
# application:technology:web_archiving
# document:genre:WWW
# research:issue:ir
# application:feature:personalization
# application:feature:profiling
# research:issue:user_engagement
# task:work:academic
# task:work:collaboration
# document:topic:health:cancer
# document:topic:crime
# application:technology:life-logging
# task:cross-session_search
# application:technology:AR/VR
# document:topic:government:NSA
# user:LGBTQ+
# application:feature:advertising
# task:work:daily_activities
# application:messenger:Slack
# application:technology:digital_assistant
# application:desktop
# task:entity_search
# document:topic:air_quality
# user:issue:information_behavior
# document:topic:finance
# application:technology:augmented_reality
# application:productivity_software
# task:work:design
# document:topic:journalism
# research:issue:proactive_IR; application:feature:proactive_IR
# application:technology:chatbots
# user:issue:user_behavior
# task:work:reading
# document:type:patents
# application:technology:search_assistance
# document:genre:TV
# document:type:audio_visual
# ~:e-services
# ~:intranet
# application:feature:query_suggestion
# application:feature:summarization
# document:issue:CLIR; research:issue:CLIR
# application:feature:visualization:non_verbal_access
# user:disabilities:dyslexia
# user:health:dyslexia
# document:type:3D_objects
# application:feature:search_engines:advertisement
# application:feature:real-time_summarization
# task:work:e-commerce:amazon
# document:topic:food
# task:complex_search
# research:issue:ethics
# document:topic:food:recipe_recommendation; application:food:recipe_recommendation
# document:media type:audio
# document:type:IT
# research:iir
# task:context:theatre
# application:digital_library
# task:context:academic_search
# document:genre:social_media
